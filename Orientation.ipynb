# %% [markdown]
# <a href="https://colab.research.google.com/github/thompsontheo155/M-L-with-PythonBootCamp/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of  String

# %%
Greeting ="What up, doctor"
print (Greeting)
# Out:
# What up, doctor

# %% [markdown]
# Example of addition

# %%
A=2
B=3
C=A+B
print (C)
# Out:
# 5
